# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaileshKrCh/Machine_Learning/blob/main/1_Neuron.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn

# %%
#input
torch.manual_seed(42)
inputs=torch.tensor([1.0,2.0,3.0])
neuron=nn.Linear(in_features=3,out_features=1)
output=neuron(inputs)
output
# Out:
# tensor([1.5244], grad_fn=<ViewBackward0>)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[ 0.4414,  0.4792, -0.1353]], requires_grad=True)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.5304], requires_grad=True)

# %%
# verify .... formula
neuron.weight @ inputs + neuron.bias
# Out:
# tensor([1.5244], grad_fn=<AddBackward0>)
