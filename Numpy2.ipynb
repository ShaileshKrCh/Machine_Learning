# %% [markdown]
# <a href="https://colab.research.google.com/github/ShaileshKrCh/Machine_Learning/blob/main/Numpy2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1.Numpy Random

# %%
from numpy import random

x=random.randint(100, size=(5))

print(x)
# Out:
# [10 54 35 75 48]

# %%
from numpy import random

x = random.randint(100, size=(3, 5))

print(x)
# Out:
# [[23 24 93 90 71]
#  [38 56 30 39 53]
#  [40 50 73 86 43]]

# %%
from numpy import random

x = random.rand(5)

print(x)
# Out:
# [0.90015545 0.54319127 0.22679602 0.06375375 0.7847792 ]

# %%
from numpy import random

x = random.rand(3, 5)

print(x)
# Out:
# [[0.43935063 0.80748591 0.98109824 0.75358548 0.61390114]
#  [0.82194756 0.90893682 0.32213944 0.06418802 0.32322813]
#  [0.09137996 0.81443162 0.8473967  0.69324778 0.91632811]]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], size=(3, 5))

print(x)
# Out:
# [[5 5 5 7 5]
#  [7 7 9 3 7]
#  [7 7 9 9 5]]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(100))

print(x)
# Out:
# [7 7 5 7 7 3 7 7 3 5 5 7 7 3 5 7 3 5 7 3 5 5 3 5 3 5 5 5 7 7 5 5 7 7 7 3 7
#  7 5 5 7 7 5 7 7 7 7 7 7 3 7 7 7 7 7 7 5 5 7 7 7 5 7 5 7 5 7 5 7 7 7 7 5 7
#  7 7 5 7 7 7 7 7 5 7 3 5 7 5 3 5 7 7 3 7 7 7 7 5 7 5]

# %%
from numpy import random

x = random.choice([3, 5, 7, 9], p=[0.1, 0.3, 0.6, 0.0], size=(3, 5))

print(x)
# Out:
# [[7 5 7 5 7]
#  [5 7 7 7 7]
#  [7 7 5 7 7]]

# %%
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

random.shuffle(arr)

print(arr)
# Out:
# [4 2 3 5 1]

# %%
from numpy import random
import numpy as np

arr = np.array([1, 2, 3, 4, 5])

print(random.permutation(arr))
# Out:
# [2 5 1 4 3]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 3, 4, 5])

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot([0, 1, 2, 3, 4, 5], kind="kde")

plt.show()

# %%
from numpy import random

x = random.normal(size=(2, 3))

print(x)
# Out:
# [[-1.85335626 -0.67143627  2.05890427]
#  [ 1.10813597  0.79689615 -1.62554235]]

# %%
from numpy import random

x = random.normal(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[ 2.96262078  4.6332193   0.50686635]
#  [ 0.89867203 -1.4880665   6.21090852]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.normal(size=1000), kind="kde")

plt.show()

# %%
from numpy import random

x = random.binomial(n=10, p=0.5, size=10)

print(x)
# Out:
# [3 4 8 5 7 7 4 3 4 3]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.binomial(n=10, p=0.5, size=1000))

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

data = {
  "normal": random.normal(loc=50, scale=5, size=1000),
  "binomial": random.binomial(n=100, p=0.5, size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
from numpy import random

x = random.poisson(lam=2, size=10)

print(x)
# Out:
# [2 1 1 2 2 2 2 2 3 1]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.poisson(lam=2, size=1000))

plt.show()

# %%
from numpy import random

x = random.uniform(size=(2, 3))

print(x)
# Out:
# [[0.87183614 0.20687787 0.9185327 ]
#  [0.57712403 0.39119615 0.09567916]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.uniform(size=1000), kind="kde")

plt.show()

# %%
from numpy import random

x = random.logistic(loc=1, scale=2, size=(2, 3))

print(x)
# Out:
# [[-5.66792612 -0.45424405  6.28367264]
#  [-5.24322118  2.9685675   4.79263991]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.logistic(size=1000), kind="kde")

plt.show()

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

data = {
  "normal": random.normal(scale=2, size=1000),
  "logistic": random.logistic(size=1000)
}

sns.displot(data, kind="kde")

plt.show()

# %%
from numpy import random

x = random.multinomial(n=6, pvals=[1/6, 1/6, 1/6, 1/6, 1/6, 1/6])

print(x)
# Out:
# [2 1 0 1 2 0]

# %%
from numpy import random

x = random.exponential(scale=2, size=(2, 3))

print(x)
# Out:
# [[2.48272171 0.97214947 0.65071342]
#  [2.39578715 1.73475659 0.31093501]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.exponential(size=1000), kind="kde")

plt.show()

# %%
from numpy import random

x = random.chisquare(df=2, size=(2, 3))

print(x)
# Out:
# [[3.29037882 0.69330704 0.45718347]
#  [0.02259526 2.13098551 0.46506064]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.chisquare(df=1, size=1000), kind="kde")

plt.show()

# %%
from numpy import random

x = random.rayleigh(scale=2, size=(2, 3))

print(x)
# Out:
# [[2.79926891 1.99758769 0.99938979]
#  [2.31154482 3.0387296  1.81417103]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.rayleigh(size=1000), kind="kde")

plt.show()

# %%
from numpy import random

x = random.pareto(a=2, size=(2, 3))

print(x)
# Out:
# [[1.34602965 0.04379675 0.21868822]
#  [0.19202819 0.17390089 0.85769742]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.displot(random.pareto(a=2, size=1000))

plt.show()

# %%
from numpy import random

x = random.zipf(a=2, size=(2, 3))

print(x)
# Out:
# [[2 3 1]
#  [3 1 1]]

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

x = random.zipf(a=2, size=1000)
sns.displot(x[x<10])

plt.show()
